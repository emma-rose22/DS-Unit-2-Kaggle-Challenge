# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 2, Module 4*
#
# ---

# %%
# Classification Metrics

## Assignment
- [X] If you haven't yet, [review requirements for your portfolio project](https://lambdaschool.github.io/ds/unit2), then submit your dataset.
- [ ] Plot a confusion matrix for your Tanzania Waterpumps model.
- [ ] Continue to participate in our Kaggle challenge. Every student should have made at least one submission that scores at least 70% accuracy (well above the majority class baseline).
- [ ] Submit your final predictions to our Kaggle competition. Optionally, go to **My Submissions**, and _"you may select up to 1 submission to be used to count towards your final leaderboard score."_
- [ ] Commit your notebook to your fork of the GitHub repo.
- [ ] Read [Maximizing Scarce Maintenance Resources with Data: Applying predictive modeling, precision at k, and clustering to optimize impact](https://towardsdatascience.com/maximizing-scarce-maintenance-resources-with-data-8f3491133050), by Lambda DS3 student Michael Brady. His blog post extends the Tanzania Waterpumps scenario, far beyond what's in the lecture notebook.


## Stretch Goals

### Reading
- [Attacking discrimination with smarter machine learning](https://research.google.com/bigpicture/attacking-discrimination-in-ml/), by Google Research, with  interactive visualizations. _"A threshold classifier essentially makes a yes/no decision, putting things in one category or another. We look at how these classifiers work, ways they can potentially be unfair, and how you might turn an unfair classifier into a fairer one. As an illustrative example, we focus on loan granting scenarios where a bank may grant or deny a loan based on a single, automatically computed number such as a credit score."_
- [Notebook about how to calculate expected value from a confusion matrix by treating it as a cost-benefit matrix](https://github.com/podopie/DAT18NYC/blob/master/classes/13-expected_value_cost_benefit_analysis.ipynb)
- [Simple guide to confusion matrix terminology](https://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/) by Kevin Markham, with video
- [Visualizing Machine Learning Thresholds to Make Better Business Decisions](https://blog.insightdatascience.com/visualizing-machine-learning-thresholds-to-make-better-business-decisions-4ab07f823415)


### Doing
- [ ] Share visualizations in our Slack channel!
- [ ] RandomizedSearchCV / GridSearchCV, for model selection. (See module 3 assignment notebook)
- [ ] More Categorical Encoding. (See module 2 assignment notebook)
- [ ] Stacking Ensemble. (See below)

### Stacking Ensemble

Here's some code you can use to "stack" multiple submissions, which is another form of ensembling:

```python
import pandas as pd

# Filenames of your submissions you want to ensemble
files = ['submission-01.csv', 'submission-02.csv', 'submission-03.csv']

target = 'status_group'
submissions = (pd.read_csv(file)[[target]] for file in files)
ensemble = pd.concat(submissions, axis='columns')
majority_vote = ensemble.mode(axis='columns')[0]

sample_submission = pd.read_csv('sample_submission.csv')
submission = sample_submission.copy()
submission[target] = majority_vote
submission.to_csv('my-ultimate-ensemble-submission.csv', index=False)
```

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Kaggle-Challenge/master/data/'
    # !pip install category_encoders==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'

# %%
import pandas as pd

# Merge train_features.csv & train_labels.csv
train = pd.merge(pd.read_csv(DATA_PATH+'waterpumps/train_features.csv'), 
                 pd.read_csv(DATA_PATH+'waterpumps/train_labels.csv'))

# Read test_features.csv & sample_submission.csv
test = pd.read_csv(DATA_PATH+'waterpumps/test_features.csv')
sample_submission = pd.read_csv(DATA_PATH+'waterpumps/sample_submission.csv')

# %%
import category_encoders as ce
import numpy as np
from sklearn.feature_selection import f_classif, SelectKBest
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import balanced_accuracy_score

# %%
#1. Begin with baselines for classification. 
#What is your baseline accuracy, if you guessed the majority class for every prediction?

# %%
#since I don't want to divide my data into train, val, test, I am going
#to make a baseline using linear classification

# %%
target = 'status_group'
features = train.columns.drop([target] + ['id', 'recorded_by'])
X_train = train[features]
y_train = train[target]

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='mean'), 
    StandardScaler(), 
    LogisticRegression(random_state=42)
)

k = 3
scores = cross_val_score(pipeline, X_train, y_train, cv=k, 
                         scoring='accuracy')
print(f'Accuracy score for {k} folds:', scores)

#pipeline.fit(X_train, y_train)
#print('Validation Score:', pipeline.score(X_val, y_val))
# Out:
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Accuracy score for 3 folds: [0.68116162 0.64085859 0.64383838]

# %%
#first model, no randomized search

# %%
from sklearn.ensemble import RandomForestClassifier

pipeline1 = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    StandardScaler(),
    RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=42)
)

k = 5
scores1 = cross_val_score(pipeline, X_train, y_train, cv=k, 
                         scoring='accuracy')
print(f'Accuracy Score for {k} folds:', scores1)
# Out:
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Accuracy Score for 5 folds: [0.62881912 0.63765676 0.63989899 0.64469697 0.6426166 ]

# %%
#second model, with randomized search, selectkbest, random forest

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

pipeline = make_pipeline(
    ce.OrdinalEncoder(),
    SimpleImputer(),
    StandardScaler(),
    SelectKBest(f_classif),
    RandomForestClassifier(random_state=42)
)

param_distributions = {
    'simpleimputer__strategy': ['mean', 'median'],
    'selectkbest__k': randint(20, 38),
    'randomforestclassifier__n_estimators': randint(50, 500),
    'randomforestclassifier__max_depth': [5, 10, 15, 20, None],
    'randomforestclassifier__max_features': uniform(0, 1)
}

search3 = RandomizedSearchCV(
    pipeline,
    param_distributions= param_distributions,
    n_iter=20,
    cv = 5,
    scoring='accuracy',
    verbose=10,
    return_train_score=True,
    n_jobs=-1
)

search3.fit(X_train, y_train);

k = 5
scores3 = cross_val_score(pipeline, X_train, y_train, cv=k, 
                         scoring='accuracy')
print(f'Accuracy Score for {k} folds:', scores3)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 21.8min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 31.5min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 34.0min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 35.5min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 40.3min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 51.6min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 57.6min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 60.0min finished
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy Score for 5 folds: [0.75439778 0.73655416 0.73686869 0.73964646 0.74187574]

# %%
print('Model Hyperparameters:')
print(pipeline.named_steps['randomforestclassifier'])
print(pipeline.named_steps['simpleimputer'])
print(pipeline.named_steps['selectkbest'])
# Out:
# Model Hyperparameters:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators='warn',
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='mean', verbose=0)
# SelectKBest(k=10, score_func=<function f_classif at 0x00000283DEF5DDC8>)

# %%
pd.DataFrame(search3.cv_results_).sort_values(by='rank_test_score').T
# Out:
#                                                                                            3   \
# mean_fit_time                                                                         258.982
# std_fit_time                                                                          11.6995
# mean_score_time                                                                       4.78576
# std_score_time                                                                       0.182329
# param_randomforestclassifier__max_depth                                                    20
# param_randomforestclassifier__max_features                                           0.312156
# param_randomforestclassifier__n_estimators                                                444
# param_selectkbest__k                                                                       34
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 20, 'ran...
# split0_test_score                                                                    0.815588
# split1_test_score                                                                    0.807929
# split2_test_score                                                                    0.812458
# split3_test_score                                                                    0.808333
# split4_test_score                                                                    0.809816
# mean_test_score                                                                      0.810825
# std_test_score                                                                     0.00286247
# rank_test_score                                                                             1
# split0_train_score                                                                   0.971317
# split1_train_score                                                                   0.969802
# split2_train_score                                                                    0.97037
# split3_train_score                                                                   0.967298
# split4_train_score                                                                   0.970477
# mean_train_score                                                                     0.969853
# std_train_score                                                                    0.00136603
#
#                                                                                            17  \
# mean_fit_time                                                                         138.648
# std_fit_time                                                                          1.86205
# mean_score_time                                                                       3.14737
# std_score_time                                                                       0.526265
# param_randomforestclassifier__max_depth                                                    20
# param_randomforestclassifier__max_features                                           0.324083
# param_randomforestclassifier__n_estimators                                                400
# param_selectkbest__k                                                                       30
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 20, 'ran...
# split0_test_score                                                                    0.812726
# split1_test_score                                                                    0.808097
# split2_test_score                                                                    0.810017
# split3_test_score                                                                    0.805219
# split4_test_score                                                                    0.808722
# mean_test_score                                                                      0.808956
# std_test_score                                                                     0.00245357
# rank_test_score                                                                             2
# split0_train_score                                                                   0.965466
# split1_train_score                                                                   0.962163
# split2_train_score                                                                   0.961658
# split3_train_score                                                                   0.959175
# split4_train_score                                                                   0.962228
# mean_train_score                                                                     0.962138
# std_train_score                                                                    0.00200481
#
#                                                                                            11  \
# mean_fit_time                                                                           213.7
# std_fit_time                                                                          1.69436
# mean_score_time                                                                       3.03036
# std_score_time                                                                       0.062521
# param_randomforestclassifier__max_depth                                                    20
# param_randomforestclassifier__max_features                                            0.56095
# param_randomforestclassifier__n_estimators                                                381
# param_selectkbest__k                                                                       28
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 20, 'ran...
# split0_test_score                                                                    0.812642
# split1_test_score                                                                    0.808602
# split2_test_score                                                                    0.809175
# split3_test_score                                                                    0.805219
# split4_test_score                                                                     0.80687
# mean_test_score                                                                      0.808502
# std_test_score                                                                     0.00249186
# rank_test_score                                                                             3
# split0_train_score                                                                   0.965908
# split1_train_score                                                                   0.964141
# split2_train_score                                                                   0.964078
# split3_train_score                                                                   0.962647
# split4_train_score                                                                   0.965427
# mean_train_score                                                                      0.96444
# std_train_score                                                                    0.00114574
#
#                                                                                            1   \
# mean_fit_time                                                                         176.713
# std_fit_time                                                                          4.89846
# mean_score_time                                                                       2.43974
# std_score_time                                                                       0.171543
# param_randomforestclassifier__max_depth                                                  None
# param_randomforestclassifier__max_features                                           0.390953
# param_randomforestclassifier__n_estimators                                                204
# param_selectkbest__k                                                                       36
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': None, 'r...
# split0_test_score                                                                    0.810622
# split1_test_score                                                                    0.805656
# split2_test_score                                                                    0.805135
# split3_test_score                                                                    0.806397
# split4_test_score                                                                    0.804176
# mean_test_score                                                                      0.806397
# std_test_score                                                                     0.00223283
# rank_test_score                                                                             4
# split0_train_score                                                                   0.999937
# split1_train_score                                                                   0.999937
# split2_train_score                                                                   0.999916
# split3_train_score                                                                   0.999958
# split4_train_score                                                                          1
# mean_train_score                                                                     0.999949
# std_train_score                                                                   2.85454e-05
#
#                                                                                            13  \
# mean_fit_time                                                                          355.76
# std_fit_time                                                                          8.37056
# mean_score_time                                                                       2.26975
# std_score_time                                                                       0.355533
# param_randomforestclassifier__max_depth                                                    20
# param_randomforestclassifier__max_features                                           0.809581
# param_randomforestclassifier__n_estimators                                                317
# param_selectkbest__k                                                                       35
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 20, 'ran...
# split0_test_score                                                                    0.808097
# split1_test_score                                                                    0.804309
# split2_test_score                                                                    0.805808
# split3_test_score                                                                    0.801263
# split4_test_score                                                                    0.804765
# mean_test_score                                                                      0.804848
# std_test_score                                                                     0.00221947
# rank_test_score                                                                             5
# split0_train_score                                                                   0.972032
# split1_train_score                                                                   0.972664
# split2_train_score                                                                   0.974074
# split3_train_score                                                                   0.970539
# split4_train_score                                                                   0.972728
# mean_train_score                                                                     0.972407
# std_train_score                                                                     0.0011471
#
#                                                                                            6   \
# mean_fit_time                                                                         223.318
# std_fit_time                                                                          14.0615
# mean_score_time                                                                       4.42439
# std_score_time                                                                        1.28306
# param_randomforestclassifier__max_depth                                                    15
# param_randomforestclassifier__max_features                                           0.367746
# param_randomforestclassifier__n_estimators                                                482
# param_selectkbest__k                                                                       30
# param_simpleimputer__strategy                                                          median
# params                                      {'randomforestclassifier__max_depth': 15, 'ran...
# split0_test_score                                                                    0.808686
# split1_test_score                                                                    0.802037
# split2_test_score                                                                    0.804461
# split3_test_score                                                                    0.801684
# split4_test_score                                                                     0.80426
# mean_test_score                                                                      0.804226
# std_test_score                                                                     0.00249832
# rank_test_score                                                                             6
# split0_train_score                                                                   0.890844
# split1_train_score                                                                   0.883836
# split2_train_score                                                                   0.883986
# split3_train_score                                                                   0.882092
# split4_train_score                                                                   0.883801
# mean_train_score                                                                     0.884912
# std_train_score                                                                    0.00304592
#
#                                                                                            2   \
# mean_fit_time                                                                         393.076
# std_fit_time                                                                          1.12998
# mean_score_time                                                                       3.73478
# std_score_time                                                                       0.260284
# param_randomforestclassifier__max_depth                                                    15
# param_randomforestclassifier__max_features                                           0.686272
# param_randomforestclassifier__n_estimators                                                433
# param_selectkbest__k                                                                       30
# param_simpleimputer__strategy                                                          median
# params                                      {'randomforestclassifier__max_depth': 15, 'ran...
# split0_test_score                                                                    0.805993
# split1_test_score                                                                    0.800943
# split2_test_score                                                                    0.804125
# split3_test_score                                                                    0.799579
# split4_test_score                                                                    0.803586
# mean_test_score                                                                      0.802845
# std_test_score                                                                     0.00229701
# rank_test_score                                                                             7
# split0_train_score                                                                   0.890696
# split1_train_score                                                                   0.887982
# split2_train_score                                                                   0.888931
# split3_train_score                                                                   0.885543
# split4_train_score                                                                   0.889735
# mean_train_score                                                                     0.888577
# std_train_score                                                                    0.00176174
#
#                                                                                            19  \
# mean_fit_time                                                                         32.8407
# std_fit_time                                                                          1.84665
# mean_score_time                                                                      0.846895
# std_score_time                                                                        0.10137
# param_randomforestclassifier__max_depth                                                    20
# param_randomforestclassifier__max_features                                           0.445792
# param_randomforestclassifier__n_estimators                                                 90
# param_selectkbest__k                                                                       23
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 20, 'ran...
# split0_test_score                                                                    0.804057
# split1_test_score                                                                    0.796229
# split2_test_score                                                                    0.799495
# split3_test_score                                                                     0.79436
# split4_test_score                                                                    0.792053
# mean_test_score                                                                      0.797239
# std_test_score                                                                     0.00418995
# rank_test_score                                                                             8
# split0_train_score                                                                   0.956986
# split1_train_score                                                                   0.936152
# split2_train_score                                                                   0.940678
# split3_train_score                                                                   0.936027
# split4_train_score                                                                   0.942427
# mean_train_score                                                                     0.942454
# std_train_score                                                                    0.00768568
#
#                                                                                            18  \
# mean_fit_time                                                                         127.257
# std_fit_time                                                                          2.29736
# mean_score_time                                                                       1.75543
# std_score_time                                                                       0.338103
# param_randomforestclassifier__max_depth                                                    20
# param_randomforestclassifier__max_features                                           0.680705
# param_randomforestclassifier__n_estimators                                                253
# param_selectkbest__k                                                                       24
# param_simpleimputer__strategy                                                          median
# params                                      {'randomforestclassifier__max_depth': 20, 'ran...
# split0_test_score                                                                    0.804057
# split1_test_score                                                                    0.795135
# split2_test_score                                                                    0.799832
# split3_test_score                                                                    0.792424
# split4_test_score                                                                     0.79441
# mean_test_score                                                                      0.797172
# std_test_score                                                                     0.00421422
# rank_test_score                                                                             9
# split0_train_score                                                                   0.959574
# split1_train_score                                                                   0.940024
# split2_train_score                                                                   0.941477
# split3_train_score                                                                   0.938973
# split4_train_score                                                                   0.941017
# mean_train_score                                                                     0.944213
# std_train_score                                                                    0.00772874
#
#                                                                                            12  \
# mean_fit_time                                                                         21.3625
# std_fit_time                                                                         0.756782
# mean_score_time                                                                       1.07618
# std_score_time                                                                       0.150182
# param_randomforestclassifier__max_depth                                                    20
# param_randomforestclassifier__max_features                                           0.232645
# param_randomforestclassifier__n_estimators                                                113
# param_selectkbest__k                                                                       20
# param_simpleimputer__strategy                                                          median
# params                                      {'randomforestclassifier__max_depth': 20, 'ran...
# split0_test_score                                                                    0.797323
# split1_test_score                                                                    0.794546
# split2_test_score                                                                    0.799495
# split3_test_score                                                                    0.792761
# split4_test_score                                                                    0.791968
# mean_test_score                                                                      0.795219
# std_test_score                                                                     0.00282039
# rank_test_score                                                                            10
# split0_train_score                                                                   0.948652
# split1_train_score                                                                   0.938677
# split2_train_score                                                                   0.938215
# split3_train_score                                                                   0.937332
# split4_train_score                                                                   0.940743
# mean_train_score                                                                     0.940724
# std_train_score                                                                    0.00411936
#
#                                                                                            0   \
# mean_fit_time                                                                         73.3058
# std_fit_time                                                                           1.0473
# mean_score_time                                                                       1.41971
# std_score_time                                                                        0.27149
# param_randomforestclassifier__max_depth                                                    10
# param_randomforestclassifier__max_features                                           0.426876
# param_randomforestclassifier__n_estimators                                                131
# param_selectkbest__k                                                                       34
# param_simpleimputer__strategy                                                          median
# params                                      {'randomforestclassifier__max_depth': 10, 'ran...
# split0_test_score                                                                    0.773925
# split1_test_score                                                                    0.766855
# split2_test_score                                                                    0.772222
# split3_test_score                                                                    0.762542
# split4_test_score                                                                     0.76949
# mean_test_score                                                                      0.769007
# std_test_score                                                                     0.00402952
# rank_test_score                                                                            11
# split0_train_score                                                                   0.797807
# split1_train_score                                                                   0.793241
# split2_train_score                                                                   0.793329
# split3_train_score                                                                   0.788573
# split4_train_score                                                                    0.79096
# mean_train_score                                                                     0.792782
# std_train_score                                                                    0.00305927
#
#                                                                                            5   \
# mean_fit_time                                                                         273.662
# std_fit_time                                                                          14.5191
# mean_score_time                                                                       1.73193
# std_score_time                                                                       0.318168
# param_randomforestclassifier__max_depth                                                    10
# param_randomforestclassifier__max_features                                           0.742908
# param_randomforestclassifier__n_estimators                                                355
# param_selectkbest__k                                                                       33
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 10, 'ran...
# split0_test_score                                                                    0.769043
# split1_test_score                                                                     0.76534
# split2_test_score                                                                    0.771296
# split3_test_score                                                                    0.765488
# split4_test_score                                                                    0.772184
# mean_test_score                                                                       0.76867
# std_test_score                                                                     0.00284949
# rank_test_score                                                                            12
# split0_train_score                                                                   0.794461
# split1_train_score                                                                   0.792125
# split2_train_score                                                                   0.795223
# split3_train_score                                                                   0.792635
# split4_train_score                                                                   0.795526
# mean_train_score                                                                     0.793994
# std_train_score                                                                    0.00137235
#
#                                                                                            15  \
# mean_fit_time                                                                         112.432
# std_fit_time                                                                         0.932773
# mean_score_time                                                                       1.77789
# std_score_time                                                                       0.247859
# param_randomforestclassifier__max_depth                                                    10
# param_randomforestclassifier__max_features                                           0.580056
# param_randomforestclassifier__n_estimators                                                393
# param_selectkbest__k                                                                       23
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 10, 'ran...
# split0_test_score                                                                    0.765171
# split1_test_score                                                                    0.749011
# split2_test_score                                                                     0.75463
# split3_test_score                                                                    0.752273
# split4_test_score                                                                    0.751305
# mean_test_score                                                                      0.754478
# std_test_score                                                                     0.00564268
# rank_test_score                                                                            13
# split0_train_score                                                                   0.786149
# split1_train_score                                                                   0.769818
# split2_train_score                                                                   0.767908
# split3_train_score                                                                   0.769949
# split4_train_score                                                                   0.768865
# mean_train_score                                                                     0.772538
# std_train_score                                                                    0.00684505
#
#                                                                                            9   \
# mean_fit_time                                                                         45.0959
# std_fit_time                                                                         0.837746
# mean_score_time                                                                      0.943977
# std_score_time                                                                       0.141365
# param_randomforestclassifier__max_depth                                                     5
# param_randomforestclassifier__max_features                                           0.447058
# param_randomforestclassifier__n_estimators                                                253
# param_selectkbest__k                                                                       28
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 5, 'rand...
# split0_test_score                                                                    0.722161
# split1_test_score                                                                    0.707095
# split2_test_score                                                                    0.717845
# split3_test_score                                                                    0.715993
# split4_test_score                                                                    0.720323
# mean_test_score                                                                      0.716684
# std_test_score                                                                     0.00523492
# rank_test_score                                                                            14
# split0_train_score                                                                   0.726804
# split1_train_score                                                                   0.717439
# split2_train_score                                                                   0.715383
# split3_train_score                                                                   0.716288
# split4_train_score                                                                   0.714174
# mean_train_score                                                                     0.718018
# std_train_score                                                                     0.0045219
#
#                                                                                            14  \
# mean_fit_time                                                                         58.4201
# std_fit_time                                                                          2.63628
# mean_score_time                                                                       1.05619
# std_score_time                                                                       0.120942
# param_randomforestclassifier__max_depth                                                     5
# param_randomforestclassifier__max_features                                           0.459558
# param_randomforestclassifier__n_estimators                                                297
# param_selectkbest__k                                                                       32
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 5, 'rand...
# split0_test_score                                                                    0.723256
# split1_test_score                                                                     0.70617
# split2_test_score                                                                    0.717593
# split3_test_score                                                                    0.714983
# split4_test_score                                                                    0.719734
# mean_test_score                                                                      0.716347
# std_test_score                                                                     0.00576548
# rank_test_score                                                                            15
# split0_train_score                                                                   0.727456
# split1_train_score                                                                   0.716492
# split2_train_score                                                                    0.71513
# split3_train_score                                                                    0.71532
# split4_train_score                                                                   0.713501
# mean_train_score                                                                      0.71758
# std_train_score                                                                    0.00502935
#
#                                                                                            8   \
# mean_fit_time                                                                          16.733
# std_fit_time                                                                         0.828387
# mean_score_time                                                                      0.963142
# std_score_time                                                                       0.303761
# param_randomforestclassifier__max_depth                                                     5
# param_randomforestclassifier__max_features                                           0.202948
# param_randomforestclassifier__n_estimators                                                147
# param_selectkbest__k                                                                       30
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 5, 'rand...
# split0_test_score                                                                    0.722835
# split1_test_score                                                                    0.707095
# split2_test_score                                                                    0.715657
# split3_test_score                                                                    0.712458
# split4_test_score                                                                    0.719145
# mean_test_score                                                                      0.715438
# std_test_score                                                                     0.00542195
# rank_test_score                                                                            16
# split0_train_score                                                                   0.723142
# split1_train_score                                                                   0.716913
# split2_train_score                                                                   0.713826
# split3_train_score                                                                   0.714899
# split4_train_score                                                                   0.712512
# mean_train_score                                                                     0.716258
# std_train_score                                                                    0.00373143
#
#                                                                                            4   \
# mean_fit_time                                                                         65.1004
# std_fit_time                                                                          8.23109
# mean_score_time                                                                      0.892993
# std_score_time                                                                       0.080325
# param_randomforestclassifier__max_depth                                                     5
# param_randomforestclassifier__max_features                                           0.852269
# param_randomforestclassifier__n_estimators                                                139
# param_selectkbest__k                                                                       28
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 5, 'rand...
# split0_test_score                                                                    0.713155
# split1_test_score                                                                    0.707769
# split2_test_score                                                                    0.717256
# split3_test_score                                                                    0.718098
# split4_test_score                                                                    0.719818
# mean_test_score                                                                      0.715219
# std_test_score                                                                     0.00432098
# rank_test_score                                                                            17
# split0_train_score                                                                    0.71805
# split1_train_score                                                                   0.717587
# split2_train_score                                                                   0.716435
# split3_train_score                                                                   0.717908
# split4_train_score                                                                   0.713312
# mean_train_score                                                                     0.716658
# std_train_score                                                                    0.00176688
#
#                                                                                            7   \
# mean_fit_time                                                                          46.525
# std_fit_time                                                                          9.35016
# mean_score_time                                                                       1.01821
# std_score_time                                                                       0.308095
# param_randomforestclassifier__max_depth                                                     5
# param_randomforestclassifier__max_features                                           0.791177
# param_randomforestclassifier__n_estimators                                                191
# param_selectkbest__k                                                                       20
# param_simpleimputer__strategy                                                            mean
# params                                      {'randomforestclassifier__max_depth': 5, 'rand...
# split0_test_score                                                                    0.713492
# split1_test_score                                                                     0.70457
# split2_test_score                                                                    0.718771
# split3_test_score                                                                    0.714731
# split4_test_score                                                                    0.717629
# mean_test_score                                                                      0.713838
# std_test_score                                                                     0.00501038
# rank_test_score                                                                            18
# split0_train_score                                                                   0.716324
# split1_train_score                                                                   0.714556
# split2_train_score                                                                   0.717214
# split3_train_score                                                                   0.716414
# split4_train_score                                                                   0.711418
# mean_train_score                                                                     0.715185
# std_train_score                                                                    0.00207416
#
#                                                                                            16  \
# mean_fit_time                                                                         20.7069
# std_fit_time                                                                         0.433426
# mean_score_time                                                                       0.55931
# std_score_time                                                                       0.125169
# param_randomforestclassifier__max_depth                                                     5
# param_randomforestclassifier__max_features                                           0.563964
# param_randomforestclassifier__n_estimators                                                133
# param_selectkbest__k                                                                       20
# param_simpleimputer__strategy                                                          median
# params                                      {'randomforestclassifier__max_depth': 5, 'rand...
# split0_test_score                                                                    0.712061
# split1_test_score                                                                    0.704823
# split2_test_score                                                                     0.71936
# split3_test_score                                                                     0.71532
# split4_test_score                                                                    0.717292
# mean_test_score                                                                      0.713771
# std_test_score                                                                     0.00508011
# rank_test_score                                                                            19
# split0_train_score                                                                   0.717755
# split1_train_score                                                                   0.715019
# split2_train_score                                                                   0.716141
# split3_train_score                                                                   0.716477
# split4_train_score                                                                   0.711165
# mean_train_score                                                                     0.715311
# std_train_score                                                                    0.00224913
#
#                                                                                            10
# mean_fit_time                                                                         8.75831
# std_fit_time                                                                        0.0500218
# mean_score_time                                                                      0.831711
# std_score_time                                                                       0.119715
# param_randomforestclassifier__max_depth                                                     5
# param_randomforestclassifier__max_features                                          0.0360089
# param_randomforestclassifier__n_estimators                                                174
# param_selectkbest__k                                                                       25
# param_simpleimputer__strategy                                                          median
# params                                      {'randomforestclassifier__max_depth': 5, 'rand...
# split0_test_score                                                                    0.679825
# split1_test_score                                                                    0.688663
# split2_test_score                                                                    0.692593
# split3_test_score                                                                    0.693939
# split4_test_score                                                                    0.701128
# mean_test_score                                                                      0.691229
# std_test_score                                                                     0.00698331
# rank_test_score                                                                            20
# split0_train_score                                                                   0.681391
# split1_train_score                                                                   0.696248
# split2_train_score                                                                   0.695097
# split3_train_score                                                                    0.69758
# split4_train_score                                                                   0.696456
# mean_train_score                                                                     0.693354
# std_train_score                                                                    0.00603354

# %%
#model 4

# %%
pipeline = make_pipeline(
    ce.OrdinalEncoder(),
    SimpleImputer(strategy = 'mean'),
    StandardScaler(),
    SelectKBest(f_classif),
    RandomForestClassifier(random_state=42, max_depth=None)
)

param_distributions = {
    'selectkbest__k': randint(20, 38),
    'randomforestclassifier__n_estimators': randint(50, 500),
    'randomforestclassifier__max_features': uniform(0, 1)
}

search4 = RandomizedSearchCV(
    pipeline,
    param_distributions= param_distributions,
    n_iter=10,
    cv = 3,
    scoring='accuracy',
    verbose=10,
    return_train_score=True,
    n_jobs=-1
)

search4.fit(X_train, y_train);

k = 5
scores4 = cross_val_score(pipeline, X_train, y_train, cv=k, 
                         scoring='accuracy')
print(f'Accuracy Score for {k} folds:', scores4)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  27 out of  30 | elapsed:  9.9min remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 11.3min finished
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\rosee\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy Score for 5 folds: [0.75439778 0.73655416 0.73686869 0.73964646 0.74187574]

# %%
cd<DS-Unit-2-Kaggle-Challenge>
# Out:
# [WinError 123] The filename, directory name, or volume label syntax is incorrect: '<DS-Unit-2-Kaggle-Challenge>'
# C:\Users\rosee\DS-Unit-2-Kaggle-Challenge\module4
